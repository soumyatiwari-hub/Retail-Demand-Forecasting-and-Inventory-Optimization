# %%
import pandas as pd
import numpy as np

print("Libraries imported successfully!")
# Out:
# Running cells with 'Python 3.13.14' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/ragha/AppData/Local/Programs/Python/Python313/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
import pandas as pd
import numpy as np

print("Libraries imported successfully!")

# %%
import pandas as pd
import numpy as np

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
import os

os.getcwd()
# Out:
# 'c:\\Users\\ragha\\Downloads\\Retail-Demand-Forecasting\\notebooks'

# %%
import pandas as pd
import numpy as np

# Load datasets
calendar = pd.read_csv("../data/raw/calendar.csv")
sales = pd.read_csv("../data/raw/sales_train_validation.csv")
prices = pd.read_csv("../data/raw/sell_prices.csv")

print("Calendar:", calendar.shape)
print("Sales:", sales.shape)
print("Prices:", prices.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 5
#       1 import pandas as pd
#       2 import numpy as np
#       3
#       4 # Load datasets
# ----> 5 calendar = pd.read_csv("../data/raw/calendar.csv")
#       6 sales = pd.read_csv("../data/raw/sales_train_validation.csv")
#       7 prices = pd.read_csv("../data/raw/sell_prices.csv")
#       8
#
# ...

# %%
import pandas as pd
import numpy as np

# Load datasets
calendar = pd.read_csv("../data/raw/calendar")
sales = pd.read_csv("../data/raw/sales_train_validation")
prices = pd.read_csv("../data/raw/sell_prices")

print("Calendar:", calendar.shape)
print("Sales:", sales.shape)
print("Prices:", prices.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 5
#       1 import pandas as pd
#       2 import numpy as np
#       3
#       4 # Load datasets
# ----> 5 calendar = pd.read_csv("../data/raw/calendar")
#       6 sales = pd.read_csv("../data/raw/sales_train_validation")
#       7 prices = pd.read_csv("../data/raw/sell_prices")
#       8
#
# ...

# %%
import pandas as pd
import numpy as np

calendar = pd.read_csv("../data/raw/calendar.csv")
sales = pd.read_csv("../data/raw/sales_train_validation.csv")
prices = pd.read_csv("../data/raw/sell_prices.csv")

print("Calendar:", calendar.shape)
print("Sales:", sales.shape)
print("Prices:", prices.shape)
# Out:
# Calendar: (1969, 14)
# Sales: (30490, 1919)
# Prices: (6841121, 4)

# %%
calendar.head()
# Out:
#          date  wm_yr_wk    weekday  wday  month  year    d event_name_1  \
# 0  2011-01-29     11101   Saturday     1      1  2011  d_1          NaN
# 1  2011-01-30     11101     Sunday     2      1  2011  d_2          NaN
# 2  2011-01-31     11101     Monday     3      1  2011  d_3          NaN
# 3  2011-02-01     11101    Tuesday     4      2  2011  d_4          NaN
# 4  2011-02-02     11101  Wednesday     5      2  2011  d_5          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0          NaN          NaN          NaN        0        0        0
# 1          NaN          NaN          NaN        0        0        0
# 2          NaN          NaN          NaN        0        0        0
# 3          NaN          NaN          NaN        1        1        0
# 4          NaN          NaN          NaN        1        0        1

# %%
sales.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
#
#   state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  d_1906  d_1907  d_1908  \
# 0       CA    0    0    0    0  ...       1       3       0       1       1
# 1       CA    0    0    0    0  ...       0       0       0       0       0
# 2       CA    0    0    0    0  ...       2       1       2       1       1
# 3       CA    0    0    0    0  ...       1       0       5       4       1
# 4       CA    0    0    0    0  ...       2       1       1       0       1
#
#    d_1909  d_1910  d_1911  d_1912  d_1913
# ...

# %%
prices.head()
# Out:
#   store_id        item_id  wm_yr_wk  sell_price
# 0     CA_1  HOBBIES_1_001     11325        9.58
# 1     CA_1  HOBBIES_1_001     11326        9.58
# 2     CA_1  HOBBIES_1_001     11327        8.26
# 3     CA_1  HOBBIES_1_001     11328        8.26
# 4     CA_1  HOBBIES_1_001     11329        8.26

# %%
calendar.isnull().sum()
# Out:
# date               0
# wm_yr_wk           0
# weekday            0
# wday               0
# month              0
# year               0
# d                  0
# event_name_1    1807
# event_type_1    1807
# event_name_2    1964
# event_type_2    1964
# snap_CA            0
# snap_TX            0
# snap_WI            0
# dtype: int64

# %%
sales.isnull().sum()
# Out:
# id          0
# item_id     0
# dept_id     0
# cat_id      0
# store_id    0
#            ..
# d_1909      0
# d_1910      0
# d_1911      0
# d_1912      0
# d_1913      0
# Length: 1919, dtype: int64

# %%
prices.isnull().sum()
# Out:
# store_id      0
# item_id       0
# wm_yr_wk      0
# sell_price    0
# dtype: int64

# %%
git add .
# Out:
#   Cell In[14], line 1
#     git add .
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

sales = pd.read_csv("../data/raw/sales_train_validation.csv")
calendar = pd.read_csv("../data/raw/calendar.csv")
prices = pd.read_csv("../data/raw/sell_prices.csv")

# %%
print("Sales Shape:", sales.shape)
print("Calendar Shape:", calendar.shape)
print("Prices Shape:", prices.shape)
# Out:
# Sales Shape: (30490, 1919)
# Calendar Shape: (1969, 14)
# Prices Shape: (6841121, 4)

# %%
sales.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
#
#   state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  d_1906  d_1907  d_1908  \
# 0       CA    0    0    0    0  ...       1       3       0       1       1
# 1       CA    0    0    0    0  ...       0       0       0       0       0
# 2       CA    0    0    0    0  ...       2       1       2       1       1
# 3       CA    0    0    0    0  ...       1       0       5       4       1
# 4       CA    0    0    0    0  ...       2       1       1       0       1
#
#    d_1909  d_1910  d_1911  d_1912  d_1913
# ...

# %%
calendar.head()
# Out:
#          date  wm_yr_wk    weekday  wday  month  year    d event_name_1  \
# 0  2011-01-29     11101   Saturday     1      1  2011  d_1          NaN
# 1  2011-01-30     11101     Sunday     2      1  2011  d_2          NaN
# 2  2011-01-31     11101     Monday     3      1  2011  d_3          NaN
# 3  2011-02-01     11101    Tuesday     4      2  2011  d_4          NaN
# 4  2011-02-02     11101  Wednesday     5      2  2011  d_5          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0          NaN          NaN          NaN        0        0        0
# 1          NaN          NaN          NaN        0        0        0
# 2          NaN          NaN          NaN        0        0        0
# 3          NaN          NaN          NaN        1        1        0
# 4          NaN          NaN          NaN        1        0        1

# %%
prices.head()
# Out:
#   store_id        item_id  wm_yr_wk  sell_price
# 0     CA_1  HOBBIES_1_001     11325        9.58
# 1     CA_1  HOBBIES_1_001     11326        9.58
# 2     CA_1  HOBBIES_1_001     11327        8.26
# 3     CA_1  HOBBIES_1_001     11328        8.26
# 4     CA_1  HOBBIES_1_001     11329        8.26

# %%
print("Sales Missing Values")
print(sales.isnull().sum())

print("\nCalendar Missing Values")
print(calendar.isnull().sum())

print("\nPrices Missing Values")
print(prices.isnull().sum())
# Out:
# Sales Missing Values
# id          0
# item_id     0
# dept_id     0
# cat_id      0
# store_id    0
#            ..
# d_1909      0
# d_1910      0
# d_1911      0
# d_1912      0
# d_1913      0
# Length: 1919, dtype: int64
#
# Calendar Missing Values
# date               0
# wm_yr_wk           0
# weekday            0
# wday               0
# month              0
# year               0
# d                  0
# event_name_1    1807
# event_type_1    1807
# event_name_2    1964
# event_type_2    1964
# snap_CA            0
# snap_TX            0
# snap_WI            0
# dtype: int64
#
# Prices Missing Values
# store_id      0
# item_id       0
# wm_yr_wk      0
# sell_price    0
# dtype: int64

# %%
print("Sales:", sales.duplicated().sum())
print("Calendar:", calendar.duplicated().sum())
print("Prices:", prices.duplicated().sum())
# Out:
# Sales: 0
# Calendar: 0
# Prices: 0

# %% [markdown]
# ## Initial Data Exploration
#
# ### Datasets Loaded
# - sales_train_validation.csv
# - calendar.csv
# - sell_prices.csv
#
# ### Checks Performed
# - Dataset shape
# - Column names
# - Data types
# - Missing values
# - Duplicate records
#
# ### Observations
# - Sales data contains daily product sales.
# - Calendar data includes holidays and events.
# - Price data contains weekly selling prices.
# - Missing values exist in event-related columns, which is expected.
